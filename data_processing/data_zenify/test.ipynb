# %%
import numpy as np
import pandas as pd
import cv2
import dlib
import os
import matplotlib.pyplot as plt

# %%
DATA_CSV = './icml_face_data.csv'
data = pd.read_csv(DATA_CSV)

# %%
train_split = data[data['Usage'] == 'Training'].drop(labels='Usage', axis=1)
valid_split = data[data['Usage'] == 'PublicTest'].drop(labels='Usage', axis=1)
test_split = data[data['Usage'] == 'PrivateTest'].drop(labels='Usage', axis=1)

# %%
test = train_split.iloc[1000]['pixels']
test2 = np.array([int(x) for x in test.split(' ')]).reshape(48, 48)
test = np.array([np.array([int(x) for x in test.split(' ')]).reshape(48, 48)] * 3).swapaxes(1, 2)
test2 = cv2.resize(np.float32(test2), dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
test2 = np.uint8(test2)


plt.imshow(test2)

# %%
from data_kaggle import get_masked_face

plt.imshow(get_masked_face(np.uint8(test2)))
